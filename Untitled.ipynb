# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

import matplotlib.mlab
xi = np.linspace(4, 8, 10)
yi = np.linspace(1, 4, 10)
zi = matplotlib.mlab.griddata(x, y, z, xi, yi, interp='linear')
plt.contour(xi, yi, zi)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-99fe0eb71c2e> in <module>()
#       7 xi = np.linspace(4, 8, 10)
#       8 yi = np.linspace(1, 4, 10)
# ----> 9 zi = matplotlib.mlab.griddata(x, y, z, xi, yi, interp='linear')
#      10 plt.contour(xi, yi, zi)
#
# NameError: name 'x' is not defined

# %%
x = [4,6,8,4,6,8,4,6,8,4,6,8]
y = [1,1,1,2,2,2,3,3,3,4,4,4]
z = [3,8,-9,10,-1,-8,8,-9,0,-1,-8,8]

# %%
from numpy.random import uniform, seed
npts = 10
x = uniform(-2, 2, npts)
y = uniform(-2, 2, npts)
print x
print y
z = x*np.exp(-x**2 - y**2)
print z
# Out:
# [ 1.11827932 -1.35571207  0.33225928  1.51010692 -0.48884189  0.04543068
#  -0.42708439 -1.21208989  0.44522127  0.3343563 ]
# [-0.98840587  1.60926833  0.4986529   0.24349558  0.96399356 -1.58868526
#   1.41675632 -0.86217416  1.09173396 -1.84825879]
# [ 0.12054844 -0.01618981  0.23202954  0.14550679 -0.15198611  0.00363352
#  -0.04781704 -0.13263422  0.11088198  0.00981933]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import kde
plt.rcParams['figure.figsize'] = [20, 16]
# Create data: 200 points
data = np.random.multivariate_normal([0, 0], [[1, 0.5], [0.5, 3]], 200)
x, y = data.T


 
# Evaluate a gaussian kde on a regular grid of nbins x nbins over data extents
k = kde.gaussian_kde(data.T)
xi, yi = np.mgrid[x.min()*2:x.max()*2:nbins*1j, y.min()*2:y.max()*2:nbins*1j]
zi = k(np.vstack([xi.flatten(), yi.flatten()]))

 
# contour
plt.plot(x, y, '.')
plt.contour(xi, yi, zi.reshape(xi.shape),colors='green')

# %%
import matplotlib
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt


delta = 0.025
x = np.arange(-3.0, 3.0, delta)
y = np.arange(-2.0, 2.0, delta)
X, Y = np.meshgrid(x, y)
Z1 = mlab.bivariate_normal(X, Y, 1.0, 1.0, 0.0, 0.0)
Z2 = mlab.bivariate_normal(X, Y, 1.5, 0.5, 1, 1)
# difference of Gaussians
Z = 10.0 * (Z2 - Z1)



plt.contour(X, Y, Z2)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import mlpy # sudo pip install mlpy
f = np.loadtxt("spiral.data")
x, y = f[:, :2], f[:, 2]
svm = mlpy.LibSvm(svm_type='c_svc', kernel_type='rbf', gamma=100)
svm.learn(x, y)
xmin, xmax = x[:,0].min()-0.1, x[:,0].max()+0.1
ymin, ymax = x[:,1].min()-0.1, x[:,1].max()+0.1
xx, yy = np.meshgrid(np.arange(xmin, xmax, 0.01), np.arange(ymin, ymax, 0.01))
xnew = np.c_[xx.ravel(), yy.ravel()]
ynew = svm.pred(xnew).reshape(xx.shape)
fig = plt.figure(1)
plt.set_cmap(plt.cm.Paired)
plt.pcolormesh(xx, yy, ynew)
plt.scatter(x[:,0], x[:,1], c=y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-8-4f41edff7fe2> in <module>()
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 import mlpy # sudo pip install mlpy
#       4 f = np.loadtxt("spiral.data")
#       5 x, y = f[:, :2], f[:, 2]
#
# ImportError: No module named mlpy
