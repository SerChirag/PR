# %%
from helper import *
from math import log,pi

inpu_data1 = read_input('NLS_Group05/Class1.txt')
inpu_data2 = read_input('NLS_Group05/Class2.txt')

train_data1,test_data1 = part_data(inpu_data1)
train_data2,test_data2 = part_data(inpu_data2)

mean1,variance1 = get_stats(train_data1)
mean2,variance2 = get_stats(train_data2)

train_data=[train_data1,train_data2]
test_data =[test_data1, test_data2]

total_test_data = test_data1+test_data2

cov1 = cov_matrix(train_data1,mean1)
cov2 = cov_matrix(train_data2,mean2)


# For part a
def cov_task1():
    cov= matrix_add([variance1],[variance2])
    X=cov
    
    cov=matrix_add([[cov[0][0]]],[[cov[0][1]]])
    cov=cov_div(cov,6.0)
    cov=[[cov[0][0] if(i==j) else 0 for j in range(0,len(X[0]))] for i in range(0,len(X[0]))]
    return cov

# for part b
def cov_task2():
    cov1 = cov_matrix(train_data1,mean1)
    cov2 = cov_matrix(train_data2,mean2)

    cov= matrix_add(cov1,cov2)
    
    cov=cov_div(cov,3.0)
    return cov

# For part c
def cov_task3():
    cov1 = cov_diagonal(cov_matrix(train_data1,mean1))
    cov2 = cov_diagonal(cov_matrix(train_data2,mean2))

    return cov1,cov2


# print mean1, variance1
# print mean2, variance2
# print mean3, variance3

# print cov1
# print cov2
# print cov3

# print cov_task1()
# print cov_task2()
# print cov_task3()

# %%
# General function for calculating g(x)
def g_x(test_data, mean, cov):
    ans=[]
    cov_inv = inverse_matrix(cov)

#   t2 = -log(2*pi)
    t3 = log(get_determinant(cov))/2.0
    t4 = log(len(test_data)/(float)(len(total_test_data)))
    
    for i in range(0,len(test_data)):
        a = get_difference_vector(test_data[i],mean)
        b = transpose(a)
        result = matrix_multiply(a,cov_inv)
        result = matrix_multiply(result,b)
        result = result[0][0]
        t1 = -1.0*result/2.0
        ans.append(t1+t3+t4)
    return ans

# %% [markdown]
# # Function for plotting part(a,b,c,d)

# %%
import numpy as np
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.mlab as mlab

legend_facecolor='#f6ffc6'
legend_edgecolor='#ff07ff'
legend_linewidth=2
legend_loc='upper right'

c={}
c[1]='#54bdff' # blue Class Color
c[2]='#9ef442' # green
c[3]='#FFB74D' # red

c2={}
c2[1]='#2205c4' # Training Points Color
c2[2]='#388E3C'
c2[3]='#ad061f'
    
def task1234(cov_a,cov_b, contour=False):
    test_data_name = total_test_data
    res1=g_x(test_data_name, mean1, cov_a)
    res2=g_x(test_data_name, mean2, cov_b)

    def dbb():
        ans=[]
        for i in range(0,len(res1)):
    #         print res1[i],res2[i],res3[i]
            val=1
            temp=res1[i]
            if(res2[i]>temp):
                val=2
            ans.append(val)
        return ans
    ans=dbb()
    # Confusion matrix
    def conf_mat():
        m=[]
        count1=0
        count2=0
        for i in range(0, len(test_data1)):
            if(ans[i]==1):
                count1 = count1+1;
        for i in range(len(test_data1), len(total_test_data)):
            if(ans[i]==2):
                count2 = count2+1;
        mm=[count1,len(test_data1)-count1]
        m.append(mm)
        mm=[len(test_data2)-count2, count2]
        m.append(mm)
        return m

    m=conf_mat()
    accuracy=(sum([m[i][i] for i in range(0,2)]))/(float)(sum([sum(m[i]) for i in range(0,2)]))
    precision=[m[i][i]/(float)(m[0][i]+m[1][i]) for i in range(0,2)]
    recall=[m[i][i]/(float)(m[i][0]+m[i][1]) for i in range(0,2)]
    f_measure=[(2*precision[i]*recall[i])/(precision[i]+recall[i]) for i in range(0,2)]
    
    mean_precision=sum([precision[i] for i in range(0,2)])/2.0
    mean_recall=sum([recall[i] for i in range(0,2)])/2.0
    mean_f_measure=sum([f_measure[i] for i in range(0,2)])/2.0
    
    print "Confusion Matrix : {0}".format(m)
    print "Accuracy :",accuracy
    print "Precision :{0}".format(precision),"Mean Precision :",mean_precision
    print "Recall :{0}".format(recall),"Mean Recall :",mean_recall
    print "F-measure :{0}".format(f_measure),"Mean F-measure :",mean_f_measure


    X=np.linspace(-22,22,500)
    Y=np.linspace(-22,22,500)

    XX=[]
    YY=[]
    for i in range(0, len(X)):
        for j in range(0, len(X)):
            XX.append(X[i])

    for i in range(0, len(Y)):
        for j in range(0, len(Y)):
            YY.append(Y[j])

    XY=[[XX[i],YY[i]] for i in range(0,len(XX))]

    test_data_name = XY
    res1=g_x(test_data_name, mean1, cov_a)
    res2=g_x(test_data_name, mean2, cov_b)
    
    x=[]
    y=[]
    for i in range(0,4):
        vv=[]
        v=[]
        x.append(v)
        y.append(vv)

    def db123():
        for i in range(0,len(res1)):
    #         print res1[i],res2[i],res3[i]
            val=1
            temp=res1[i]
            if(res2[i]>temp):
                val=2
            x[val].append(XY[i][0])
            y[val].append(XY[i][1])

    res = db123()
    matplotlib.style.use('seaborn')
    fig, ax1 = plt.subplots(1, 1, figsize=(14,8))
#     fig.subplots_adjust(hspace=0.4, wspace=0.4)
#     fig.suptitle('Dataset 2 (Non-Linearly Separable Data) plots across Classes', fontsize=22)

    
    plt.subplot(111)

    plt.plot(x[1],y[1],c[1],marker='.',linestyle='None')
    plt.plot(x[2],y[2],c[2],marker='.',linestyle='None')

    X=[train_data1[i][0] for i in range(0,len(train_data1)) ]
    Y=[train_data1[i][1] for i in range(0,len(train_data1)) ]
    plt.plot(X,Y,c=c2[1],marker='.',linestyle='None')

    X=[train_data2[i][0] for i in range(0,len(train_data2)) ]
    Y=[train_data2[i][1] for i in range(0,len(train_data2)) ]
    plt.plot(X,Y,c=c2[2],marker='.',linestyle='None')

    plt.title('Class1 vs Class2', fontsize=16)
    
    colors = [c[1],c2[1],c[2],c2[2]]
    texts = ["Class 1","Training 1", "Class 2", "Training 2"]
    
    handles = [plt.Rectangle((0,0),1,1,color=colors[i]) for i  in range(len(texts))]
    legend=fig.legend(handles=handles, labels=texts,loc='right', ncol=1,frameon=1,
                      labelspacing=1.5, borderpad=0.75, prop=dict(weight='black',size='large'))
    
    frame = legend.get_frame()
    frame.set_facecolor(legend_facecolor)
    frame.set_edgecolor(legend_edgecolor)
    frame.set_linewidth(legend_linewidth)
    
    if(contour==True):
        delta = 0.025*100
        xu = np.arange(-22, 22, delta)
        yu = np.arange(-22, 22, delta)
        XI, YI = np.meshgrid(xu, yu)
        
        sigmax1=pow(cov_a[0][0],0.5)
        sigmay1=pow(cov_a[1][1],0.5)
        mux1=mean1[0]
        muy1=mean1[1]
        sigmaxy1 = cov_a[0][1]
        ZI1 = mlab.bivariate_normal(XI, YI, sigmax1, sigmay1, mux1, muy1,sigmaxy1)

        sigmax2=pow(cov_b[0][0],0.5)
        sigmay2=pow(cov_b[1][1],0.5)
        mux2=mean2[0]
        muy2=mean2[1]
        sigmaxy2 = cov_b[0][1]
        ZI2 = mlab.bivariate_normal(XI, YI, sigmax2, sigmay2, mux2, muy2,sigmaxy2)
        
        plt.contour(XI, YI, ZI2-ZI1,12,zorder=10,colors="white")
#         plt.contour(XI, YI, ZI2,6,zorder=10,colors="white")

# %% [markdown]
# ## Calling part(a)

# %%
task1234(cov_task1(),cov_task1())
# Out:
# Confusion Matrix : [[165, 161], [142, 184]]
# Accuracy : 0.53527607362
# Precision :[0.5374592833876222, 0.5333333333333333] Mean Precision : 0.53539630836
# Recall :[0.5061349693251533, 0.5644171779141104] Mean Recall : 0.53527607362
# F-measure :[0.5213270142180094, 0.5484351713859911] Mean F-measure : 0.534881092802

# %%
task1234(cov_task1(),cov_task1(),True)
# Out:
# Confusion Matrix : [[165, 161], [142, 184]]
# Accuracy : 0.53527607362
# Precision :[0.5374592833876222, 0.5333333333333333] Mean Precision : 0.53539630836
# Recall :[0.5061349693251533, 0.5644171779141104] Mean Recall : 0.53527607362
# F-measure :[0.5213270142180094, 0.5484351713859911] Mean F-measure : 0.534881092802
# /home/prabhakar/anaconda3/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:156: MatplotlibDeprecationWarning: The bivariate_normal function was deprecated in version 2.2.
# /home/prabhakar/anaconda3/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:163: MatplotlibDeprecationWarning: The bivariate_normal function was deprecated in version 2.2.

# %% [markdown]
# ## Calling part(b)

# %%
task1234(cov_task2(),cov_task2())
# Out:
# Confusion Matrix : [[164, 162], [141, 185]]
# Accuracy : 0.53527607362
# Precision :[0.5377049180327869, 0.5331412103746398] Mean Precision : 0.535423064204
# Recall :[0.5030674846625767, 0.5674846625766872] Mean Recall : 0.53527607362
# F-measure :[0.5198098256735341, 0.549777117384844] Mean F-measure : 0.534793471529

# %%
task1234(cov_task2(),cov_task2(), True)
# Out:
# Confusion Matrix : [[164, 162], [141, 185]]
# Accuracy : 0.53527607362
# Precision :[0.5377049180327869, 0.5331412103746398] Mean Precision : 0.535423064204
# Recall :[0.5030674846625767, 0.5674846625766872] Mean Recall : 0.53527607362
# F-measure :[0.5198098256735341, 0.549777117384844] Mean F-measure : 0.534793471529
# /home/prabhakar/anaconda3/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:156: MatplotlibDeprecationWarning: The bivariate_normal function was deprecated in version 2.2.
# /home/prabhakar/anaconda3/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:163: MatplotlibDeprecationWarning: The bivariate_normal function was deprecated in version 2.2.

# %% [markdown]
# ## Calling part(c)

# %%
cov_a,cov_b=cov_task3()
task1234(cov_a,cov_b)
# Out:
# Confusion Matrix : [[175, 151], [148, 178]]
# Accuracy : 0.541411042945
# Precision :[0.541795665634675, 0.541033434650456] Mean Precision : 0.541414550143
# Recall :[0.5368098159509203, 0.5460122699386503] Mean Recall : 0.541411042945
# F-measure :[0.539291217257319, 0.5435114503816794] Mean F-measure : 0.541401333819

# %%
task1234(cov_a,cov_b, True)
# Out:
# Confusion Matrix : [[175, 151], [148, 178]]
# Accuracy : 0.541411042945
# Precision :[0.541795665634675, 0.541033434650456] Mean Precision : 0.541414550143
# Recall :[0.5368098159509203, 0.5460122699386503] Mean Recall : 0.541411042945
# F-measure :[0.539291217257319, 0.5435114503816794] Mean F-measure : 0.541401333819
# /home/prabhakar/anaconda3/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:156: MatplotlibDeprecationWarning: The bivariate_normal function was deprecated in version 2.2.
# /home/prabhakar/anaconda3/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:163: MatplotlibDeprecationWarning: The bivariate_normal function was deprecated in version 2.2.

# %% [markdown]
# ## Calling part(d)

# %%
task1234(cov1,cov2)
# Out:
# Confusion Matrix : [[175, 151], [149, 177]]
# Accuracy : 0.539877300613
# Precision :[0.5401234567901234, 0.5396341463414634] Mean Precision : 0.539878801566
# Recall :[0.5368098159509203, 0.5429447852760736] Mean Recall : 0.539877300613
# F-measure :[0.5384615384615384, 0.5412844036697246] Mean F-measure : 0.539872971066

# %%
task1234(cov1,cov2, True)
# Out:
# Confusion Matrix : [[175, 151], [149, 177]]
# Accuracy : 0.539877300613
# Precision :[0.5401234567901234, 0.5396341463414634] Mean Precision : 0.539878801566
# Recall :[0.5368098159509203, 0.5429447852760736] Mean Recall : 0.539877300613
# F-measure :[0.5384615384615384, 0.5412844036697246] Mean F-measure : 0.539872971066
# /home/prabhakar/anaconda3/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:156: MatplotlibDeprecationWarning: The bivariate_normal function was deprecated in version 2.2.
# /home/prabhakar/anaconda3/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:163: MatplotlibDeprecationWarning: The bivariate_normal function was deprecated in version 2.2.

# %% [markdown]
# # Finished. Codes below this cell are redundant. Thanks.

# %%
import matplotlib.pyplot as plt
c={}
c[1]='#54bdff' # blue Class Color
c[2]='#9ea442' # green

c2={}
c2[1]='#d6d4fc' # Training Points Color
c2[2]='#381E3C'

X=np.linspace(-22,22,200)
Y=np.linspace(-22,22,200)

XX=[]
YY=[]
for i in range(0, len(X)):
    for j in range(0, len(X)):
        XX.append(X[i])

for i in range(0, len(Y)):
    for j in range(0, len(Y)):
        YY.append(Y[j])

XY=[[XX[i],YY[i]] for i in range(0,len(XX))]

test_data_name = XY
cov_a=cov1
cov_b=cov2
# cov_c=cov3
res1=g_x(test_data_name, mean1, cov_a)
res2=g_x(test_data_name, mean2, cov_b)
# res3=g_x(test_data_name, mean3, cov_c)
x=[]
y=[]
for i in range(0,4):
    vv=[]
    v=[]
    x.append(v)
    y.append(vv)

def db123():
    for i in range(0,len(res1)):
#         print res1[i],res2[i],res3[i]
        val=1
        temp=res1[i]
        if(res2[i]>temp):
            val=2
        x[val].append(XY[i][0])
        y[val].append(XY[i][1])

res = db123()
def maha_graph():
    ans = []
    for i in range(len(XY)):
        tutu = []
        pota1 = float(np.exp(res1[i]))
        pota2 = float(np.exp(res2[i]))
#         pota3 = float(np.exp(res3[i]))
        tutu.append(round(pota1/(float)(pota1+pota2),8))
        tutu.append(round(pota2/(float)(pota1+pota2),8))
        tutu.append(round(0.0))
        
        ans.append(tuple(tutu))
    return ans

colour_hex = maha_graph()
matplotlib.style.use('seaborn')
fig, ax1 = plt.subplots(1, 1, figsize=(14,8))
#     fig.subplots_adjust(hspace=0.4, wspace=0.4)
#     fig.suptitle('Dataset 2 (Non-Linearly Separable Data) plots across Classes', fontsize=22)

    
plt.subplot(111)
plt.scatter(XX,YY,color=colour_hex)
# plt.plot(x[1],y[1],c[1],marker='.',linestyle='None')
# plt.plot(x[2],y[2],c[2],marker='.',linestyle='None')

X=[train_data1[i][0] for i in range(0,len(train_data1)) ]
Y=[train_data1[i][1] for i in range(0,len(train_data1)) ]
plt.plot(X,Y,c=c2[1],marker='.',linestyle='None')

X=[train_data2[i][0] for i in range(0,len(train_data2)) ]
Y=[train_data2[i][1] for i in range(0,len(train_data2)) ]
plt.plot(X,Y,c=c2[2],marker='.',linestyle='None')

# plt.title('Class1 vs Class2', fontsize=16)
    
colors = ['red',c2[1],'green',c2[2]]
texts = ["Class 1","Training 1", "Class 2", "Training 2"]
    
handles = [plt.Rectangle((0,0),1,1,color=colors[i]) for i  in range(len(texts))]
legend=fig.legend(handles=handles, labels=texts,loc='right', ncol=1,frameon=1,
                      labelspacing=1.5, borderpad=0.75, prop=dict(weight='black',size='large'))
    
frame = legend.get_frame()
frame.set_facecolor(legend_facecolor)
frame.set_edgecolor(legend_edgecolor)
frame.set_linewidth(legend_linewidth)
